# %%
import pandas
import sklearn
import matplotlib
import seaborn

# %%
customers=pandas.read_csv(r"C:\Users\Sarah\Desktop\modcom\class\komba-sarah\Data Science\data\Mall_Customers.csv")
customers
# Out:
#      CustomerID  Gender  Age  Annual Income  Spending Score
# 0             1    Male   19           15.0            39.0
# 1             2    Male   21           15.0            81.0
# 2             3  Female   20           16.0             6.0
# 3             4  Female   23           16.0            77.0
# 4             5  Female   31           17.0            40.0
# ..          ...     ...  ...            ...             ...
# 195         196  Female   35          120.0            79.0
# 196         197  Female   45          126.0             NaN
# 197         198    Male   32          126.0            74.0
# 198         199    Male   32          137.0            18.0
# 199         200    Male   30          137.0            83.0
#
# [200 rows x 5 columns]

# %%
#view the first 25 rows
customers.head(25)
# Out:
#     CustomerID  Gender  Age  Annual Income  Spending Score
# 0            1    Male   19           15.0            39.0
# 1            2    Male   21           15.0            81.0
# 2            3  Female   20           16.0             6.0
# 3            4  Female   23           16.0            77.0
# 4            5  Female   31           17.0            40.0
# 5            6  Female   22           17.0            76.0
# 6            7  Female   35           18.0             6.0
# 7            8  Female   23           18.0            94.0
# 8            9    Male   64           19.0             3.0
# 9           10  Female   30           19.0            72.0
# 10          11    Male   67           19.0            14.0
# 11          12  Female   35           19.0            99.0
# 12          13  Female   58           20.0            15.0
# 13          14  Female   24           20.0            77.0
# 14          15    Male   37           20.0            13.0
# ...

# %%
#cleaning data: remove null/empty cells
customers.isnull().sum()
# Out:
# CustomerID        0
# Gender            4
# Age               0
# Annual Income     1
# Spending Score    3
# dtype: int64

# %%
#removing empty cells in column Annual Income
income_mean=customers["Annual Income"].mean()
income_mean
customers["Annual Income"].fillna(income_mean,inplace=True)
customers.isnull().sum()
# Out:
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_1124\3435028320.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers["Annual Income"].fillna(income_mean,inplace=True)
# CustomerID        0
# Gender            4
# Age               0
# Annual Income     0
# Spending Score    3
# dtype: int64

# %%
#remove empty cells in column gender, and replace with sting 'unknown'
customers["Gender"].fillna('unknown',inplace=True)
customers.isnull().sum()
# Out:
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_1124\2798751007.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers["Gender"].fillna('unknown',inplace=True)
# CustomerID        0
# Gender            0
# Age               0
# Annual Income     0
# Spending Score    3
# dtype: int64

# %%
#replace empty cells in column spending score with its mean
spending_mean=customers["Spending Score"].mean()
spending_mean
customers["Spending Score"].fillna(spending_mean,inplace=True)
customers.isnull().sum()
# Out:
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_1124\1461485117.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers["Spending Score"].fillna(spending_mean,inplace=True)
# CustomerID        0
# Gender            0
# Age               0
# Annual Income     0
# Spending Score    0
# dtype: int64

# %%
#data science:
#step 1: we do data preprocessing - identify datatypes
#step 2: dataset exploration - fetching and displaying it in a table format
# step 3: data cleaning - removing null cells
# step 4: data analysis - we use function description(),create graphs etc
# step 5: EDA or Clustering or regression etc

# %%
# step 4: data analysis - we use function describe(),create graphs etc
customers.describe()
# Out:
#        CustomerID         Age  Annual Income  Spending Score
# count  200.000000  200.000000     200.000000      200.000000
# mean   100.500000   38.850000      60.356784       50.324873
# std     57.879185   13.969007      26.107015       25.445104
# min      1.000000   18.000000      15.000000        1.000000
# 25%     50.750000   28.750000      41.500000       35.000000
# 50%    100.500000   36.000000      61.000000       50.000000
# 75%    150.250000   49.000000      78.000000       72.250000
# max    200.000000   70.000000     137.000000       99.000000

# %%
# step 5: Clustering (we are training data model not testing)
# we will be using K-Means algorithm when clusterings
#put your dataset in form of an array(unique list [])
array=customers.values
array
# Out:
# array([[1, 'Male', 19, 15.0, 39.0],
#        [2, 'Male', 21, 15.0, 81.0],
#        [3, 'Female', 20, 16.0, 6.0],
#        [4, 'Female', 23, 16.0, 77.0],
#        [5, 'Female', 31, 17.0, 40.0],
#        [6, 'Female', 22, 17.0, 76.0],
#        [7, 'Female', 35, 18.0, 6.0],
#        [8, 'Female', 23, 18.0, 94.0],
#        [9, 'Male', 64, 19.0, 3.0],
#        [10, 'Female', 30, 19.0, 72.0],
#        [11, 'Male', 67, 19.0, 14.0],
#        [12, 'Female', 35, 19.0, 99.0],
#        [13, 'Female', 58, 20.0, 15.0],
#        [14, 'Female', 24, 20.0, 77.0],
#        [15, 'Male', 37, 20.0, 13.0],
#        [16, 'Male', 22, 20.0, 79.0],
#        [17, 'Female', 35, 21.0, 35.0],
#        [18, 'Male', 20, 21.0, 66.0],
#        [19, 'Male', 52, 23.0, 29.0],
#        [20, 'Female', 35, 23.0, 98.0],
#        [21, 'Male', 35, 24.0, 35.0],
#        [22, 'Male', 25, 24.0, 73.0],
#        [23, 'Female', 46, 25.0, 5.0],
#        [24, 'Male', 31, 25.0, 73.0],
#        [25, 'Female', 54, 28.0, 14.0],
# ...

# %%
X=array[0:200,2:5] #rows,columns
X
#we are splitting the dataset bcs K-means only works with numerical data types
#note we are using X only bcs we are performing an unsupervised learning algorithm
# Out:
# array([[19, 15.0, 39.0],
#        [21, 15.0, 81.0],
#        [20, 16.0, 6.0],
#        [23, 16.0, 77.0],
#        [31, 17.0, 40.0],
#        [22, 17.0, 76.0],
#        [35, 18.0, 6.0],
#        [23, 18.0, 94.0],
#        [64, 19.0, 3.0],
#        [30, 19.0, 72.0],
#        [67, 19.0, 14.0],
#        [35, 19.0, 99.0],
#        [58, 20.0, 15.0],
#        [24, 20.0, 77.0],
#        [37, 20.0, 13.0],
#        [22, 20.0, 79.0],
#        [35, 21.0, 35.0],
#        [20, 21.0, 66.0],
#        [52, 23.0, 29.0],
#        [35, 23.0, 98.0],
#        [35, 24.0, 35.0],
#        [25, 24.0, 73.0],
#        [46, 25.0, 5.0],
#        [31, 25.0, 73.0],
#        [54, 28.0, 14.0],
#        [29, 28.0, 82.0],
#        [45, 28.0, 32.0],
#        [35, 28.0, 61.0],
#        [40, 29.0, 31.0],
#        [23, 29.0, 87.0],
#        [60, 30.0, 4.0],
#        [21, 30.0, 73.0],
#        [53, 33.0, 4.0],
#        [18, 33.0, 92.0],
#        [49, 33.0, 14.0],
#        [21, 33.0, 81.0],
#        [42, 34.0, 17.0],
# ...

# %%
#spliting into sets/clusters
from sklearn.cluster import KMeans as km
model=km(n_clusters=12,random_state=42)
model.fit(X)
#n_cluster groups our dataset(array) in groups of 12. the more the cluster/groups the better the selection
#random_state makes the dataset rows random everytime we cluster/group
# Out:
# KMeans(n_clusters=12, random_state=42)

# %%
#next we find the mean/average of the groups (analysing) 
means = model.cluster_centers_
means
# Out:
# array([[ 56.66666667,  53.21428571,  49.71428571],
#        [ 33.1       ,  74.95      ,  82.4       ],
#        [ 44.58333333, 100.91666667,  22.16666667],
#        [ 24.85714286,  24.64285714,  72.92857143],
#        [ 49.        ,  24.46153846,  11.07692308],
#        [ 25.17241379,  55.01230289,  52.62068966],
#        [ 38.83333333,  78.38888889,  10.94444444],
#        [ 32.        ,  92.38461538,  82.30769231],
#        [ 36.18181818,  29.90909091,  35.09090909],
#        [ 35.5       , 122.5       ,  71.2749577 ],
#        [ 38.85714286,  69.35714286,  40.45177665],
#        [ 26.        ,  27.625     ,  90.625     ]])

# %%
#lets create a table for our groups
clusters=pandas.DataFrame(means,columns=['Age','Income','Spending Score'] ) #dataframe is used to create rows and columns
clusters
# Out:
#           Age      Income  Spending Score
# 0   56.666667   53.214286       49.714286
# 1   33.100000   74.950000       82.400000
# 2   44.583333  100.916667       22.166667
# 3   24.857143   24.642857       72.928571
# 4   49.000000   24.461538       11.076923
# 5   25.172414   55.012303       52.620690
# 6   38.833333   78.388889       10.944444
# 7   32.000000   92.384615       82.307692
# 8   36.181818   29.909091       35.090909
# 9   35.500000  122.500000       71.274958
# 10  38.857143   69.357143       40.451777
# 11  26.000000   27.625000       90.625000

# %%
#create a column group_number, for us to see the different rows with it group
customers["group_number"]=model.labels_
customers.head(20)
# Out:
#     CustomerID  Gender  Age  Annual Income  Spending Score  group_number
# 0            1    Male   19           15.0            39.0             8
# 1            2    Male   21           15.0            81.0             3
# 2            3  Female   20           16.0             6.0             4
# 3            4  Female   23           16.0            77.0             3
# 4            5  Female   31           17.0            40.0             8
# 5            6  Female   22           17.0            76.0             3
# 6            7  Female   35           18.0             6.0             4
# 7            8  Female   23           18.0            94.0            11
# 8            9    Male   64           19.0             3.0             4
# 9           10  Female   30           19.0            72.0             3
# 10          11    Male   67           19.0            14.0             4
# 11          12  Female   35           19.0            99.0            11
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x=customers["group_number"])
#y axis =number of customers
#title = distribution of group members
# Out:
# <Axes: xlabel='group_number', ylabel='count'>

# %%
sns.pairplot(customers) #pair plot plots multiple bivariante(2 variables/columns) distribution  of a dataset

# %%
#create a barplot,scaterplot,swarmplot for columns: x=age,y=annual income, hue=group_number
