# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
groceries_df = pd.read_csv('Groceries.csv')
groceries_df
# Out:
#        Member_number        Date        itemDescription  year  month  day  \
# 0               1808  2015-07-21         tropical fruit  2015      7   21
# 1               2552  2015-05-01             whole milk  2015      5    1
# 2               2300  2015-09-19              pip fruit  2015      9   19
# 3               1187  2015-12-12       other vegetables  2015     12   12
# 4               3037  2015-01-02             whole milk  2015      1    2
# ...              ...         ...                    ...   ...    ...  ...
# 38760           4471  2014-08-10          sliced cheese  2014      8   10
# 38761           2022  2014-02-23                  candy  2014      2   23
# 38762           1097  2014-04-16               cake bar  2014      4   16
# 38763           1510  2014-03-12  fruit/vegetable juice  2014      3   12
# 38764           1521  2014-12-26               cat food  2014     12   26
#
#        day_of_week
# 0                1
# 1                4
# 2                5
# 3                5
# 4                4
# ...            ...
# 38760            6
# 38761            6
# 38762            2
# 38763            2
# 38764            4
#
# [38765 rows x 7 columns]

# %%
groceries_df.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# year               0
# month              0
# day                0
# day_of_week        0
# dtype: int64

# %%
top_items = groceries_df['itemDescription'].value_counts().head(10)

print("Top 10 most frequently purchased items:")
print(top_items)
# Out:
# Top 10 most frequently purchased items:
# itemDescription
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# root vegetables     1071
# tropical fruit      1032
# bottled water        933
# sausage              924
# citrus fruit         812
# Name: count, dtype: int64

# %%
# Create a function to get the top 5 most frequent items for a given month
def top_items_per_month(month):
    # Filter the dataset for the given month
    month_data = groceries_df[groceries_df['month'] == month]
    # Get the top 5 most frequent items
    top_items = month_data['itemDescription'].value_counts().head(5)
    return top_items

# Get the list of unique months in the dataset
unique_months = groceries_df['month'].unique()

# Dictionary to store the top items for each month
top_items_dict = {}

# Iterate through each unique month and get the top items
for month in unique_months:
    top_items_dict[month] = top_items_per_month(month)

# Print the top 5 most frequent items for each month
for month, items in top_items_dict.items():
    print(f"Month: {month}")
    print(items)
    print("\n")
# Out:
# Month: 7
# itemDescription
# whole milk          222
# other vegetables    160
# rolls/buns          135
# soda                116
# yogurt              111
# Name: count, dtype: int64
#
#
# Month: 5
# itemDescription
# whole milk          218
# other vegetables    145
# rolls/buns          142
# soda                115
# yogurt              103
# Name: count, dtype: int64
#
#
# Month: 9
# itemDescription
# whole milk          200
# other vegetables    150
# rolls/buns          147
# soda                119
# yogurt              113
# Name: count, dtype: int64
#
#
# Month: 12
# itemDescription
# whole milk          167
# other vegetables    161
# soda                130
# rolls/buns          125
# root vegetables     104
# Name: count, dtype: int64
#
#
# Month: 1
# itemDescription
# whole milk          219
# other vegetables    166
# rolls/buns          149
# soda                134
# yogurt              112
# Name: count, dtype: int64
#
#
# Month: 2
# itemDescription
# whole milk          173
# rolls/buns          159
# other vegetables    144
# soda                107
# yogurt               95
# Name: count, dtype: int64
#
#
# Month: 8
# itemDescription
# whole milk          235
# other vegetables    187
# rolls/buns          144
# soda                128
# yogurt              117
# Name: count, dtype: int64
#
#
# Month: 3
# itemDescription
# whole milk          216
# other vegetables    145
# rolls/buns          141
# yogurt              127
# soda                125
# Name: count, dtype: int64
#
#
# Month: 4
# itemDescription
# whole milk          218
# other vegetables    155
# yogurt              137
# soda                135
# rolls/buns          126
# Name: count, dtype: int64
#
#
# Month: 11
# itemDescription
# whole milk          230
# other vegetables    163
# soda                135
# rolls/buns          135
# yogurt              111
# Name: count, dtype: int64
#
#
# Month: 10
# itemDescription
# whole milk          199
# rolls/buns          163
# other vegetables    163
# soda                125
# yogurt              110
# Name: count, dtype: int64
#
#
# Month: 6
# itemDescription
# whole milk          205
# other vegetables    159
# rolls/buns          150
# soda                145
# yogurt              100
# Name: count, dtype: int64

# %%
# Categorize days into weekends(1) and weekdays(0)
groceries_df['is_weekend'] = groceries_df['day_of_week'].apply(lambda x: '1' if x >= 5 else '0')
groceries_df

import scipy.stats as stats

is_weekend = groceries_df[groceries_df['is_weekend'] == '1']['itemDescription'].count()
isnt_weekend = groceries_df[groceries_df['is_weekend']== '0']['itemDescription'].count()

t_statistic, p_value = stats.ttest_ind(a=is_weekend,b=isnt_weekend)

if p_value < 0.05:
  print("There is a significant difference in the purchase frequency of certain items on weekends versus weekdays.")
else:
  print("There is no significant difference in the purchase frequency of certain items on weekends versus weekdays.")
# Out:
# There is no significant difference in the purchase frequency of certain items on weekends versus weekdays.
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\stats\_stats_py.py:6988: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df

# %%
# Create a basket format
basket = (groceries_df.groupby(['Member_number', 'itemDescription'])['itemDescription'].count().unstack().reset_index().fillna(0).set_index('Member_number'))
# basket.head(15)

def encode_units(x):
    if x <=0:
       return 0
    if x > 0:
       return 1
basket = basket.applymap(encode_units)
# basket.head(15)

# Step 2: Apply the Apriori algorithm
frequent_itemsets = apriori(basket, min_support=0.01, use_colnames=True)

# Step 3: Generate the association rules
rules = association_rules(frequent_itemsets, metric="support", min_threshold=0.01)
rules

# Step 4: Filter to find the most common item pairs
common_item_pairs = rules[(rules['antecedents'].apply(lambda x: len(x) == 1)) & 
                          (rules['consequents'].apply(lambda x: len(x) == 1))]
common_item_pairs = common_item_pairs.sort_values(by='support', ascending=False).head(10)

print("Most common item pairs purchased together:")
print(common_item_pairs[['antecedents', 'consequents', 'support']])
# Out:
# Most common item pairs purchased together:
#              antecedents         consequents   support
# 1869  (other vegetables)        (whole milk)  0.191380
# 1868        (whole milk)  (other vegetables)  0.191380
# 2049        (rolls/buns)        (whole milk)  0.178553
# 2048        (whole milk)        (rolls/buns)  0.178553
# 2187              (soda)        (whole milk)  0.151103
# 2186        (whole milk)              (soda)  0.151103
# 2251            (yogurt)        (whole milk)  0.150590
# 2250        (whole milk)            (yogurt)  0.150590
# 1830        (rolls/buns)  (other vegetables)  0.146742
# 1831  (other vegetables)        (rolls/buns)  0.146742

# %%
import pandas
rules_df = pandas.DataFrame(rules)
rules_df
rules_df = rules_df.sort_values(by='support', ascending=False)

print("Association rules with the highest support:")
rules_df.head(10)
# Out:
# Association rules with the highest support:
#              antecedents         consequents  antecedent support  \
# 1868        (whole milk)  (other vegetables)            0.458184
# 1869  (other vegetables)        (whole milk)            0.376603
# 2048        (whole milk)        (rolls/buns)            0.458184
# 2049        (rolls/buns)        (whole milk)            0.349666
# 2187              (soda)        (whole milk)            0.313494
# 2186        (whole milk)              (soda)            0.458184
# 2250        (whole milk)            (yogurt)            0.458184
# 2251            (yogurt)        (whole milk)            0.282966
# 1830        (rolls/buns)  (other vegetables)            0.349666
# 1831  (other vegetables)        (rolls/buns)            0.376603
#
#       consequent support   support  confidence      lift  leverage  \
# 1868            0.376603  0.191380    0.417693  1.109106  0.018827
# 1869            0.458184  0.191380    0.508174  1.109106  0.018827
# 2048            0.349666  0.178553    0.389698  1.114484  0.018342
# 2049            0.458184  0.178553    0.510638  1.114484  0.018342
# 2187            0.458184  0.151103    0.481997  1.051973  0.007465
# 2186            0.313494  0.151103    0.329787  1.051973  0.007465
# 2250            0.282966  0.150590    0.328667  1.161510  0.020940
# 2251            0.458184  0.150590    0.532185  1.161510  0.020940
# 1830            0.376603  0.146742    0.419663  1.114335  0.015056
# 1831            0.349666  0.146742    0.389646  1.114335  0.015056
#
#       conviction  zhangs_metric
# 1868    1.070564       0.181562
# 1869    1.101643       0.157802
# 2048    1.065592       0.189591
# 2049    1.107190       0.157955
# 2187    1.045971       0.071966
# 2186    1.024310       0.091184
# 2250    1.068076       0.256640
# 2251    1.158185       0.193926
# 1830    1.074197       0.157772
# 1831    1.065502       0.164589

# %%
rules_df = rules_df.sort_values(by='confidence', ascending=False)

print("Association rules with the highest confidence:")
rules_df.head(10)
# Out:
# Association rules with the highest confidence:
#                                              antecedents   consequents  \
# 7197                               (domestic eggs, meat)  (whole milk)
# 5866                  (chocolate, fruit/vegetable juice)  (whole milk)
# 15364  (bottled water, rolls/buns, yogurt, other vege...  (whole milk)
# 11849                 (bottled water, pip fruit, yogurt)  (whole milk)
# 12213                  (rolls/buns, yogurt, brown bread)  (whole milk)
# 11345     (bottled water, other vegetables, brown bread)  (whole milk)
# 11317                 (rolls/buns, bottled beer, yogurt)  (whole milk)
# 13025                               (curd, soda, yogurt)  (whole milk)
# 15424  (rolls/buns, shopping bags, yogurt, other vege...  (whole milk)
# 14551                        (pastry, pip fruit, yogurt)  (whole milk)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 7197             0.013084            0.458184  0.010262    0.784314  1.711789
# 5866             0.014366            0.458184  0.010775    0.750000  1.636898
# 15364            0.014110            0.458184  0.010518    0.745455  1.626978
# 11849            0.013853            0.458184  0.010262    0.740741  1.616689
# 12213            0.017445            0.458184  0.012827    0.735294  1.604802
# 11345            0.016675            0.458184  0.012057    0.723077  1.578138
# 11317            0.019241            0.458184  0.013853    0.720000  1.571422
# 13025            0.015136            0.458184  0.010775    0.711864  1.553666
# 15424            0.014110            0.458184  0.010005    0.709091  1.547613
# 14551            0.014879            0.458184  0.010518    0.706897  1.542823
#
#        leverage  conviction  zhangs_metric
# 7197   0.004267    2.512057       0.421328
# 5866   0.004192    2.167265       0.394760
# 15364  0.004053    2.128564       0.390879
# 11849  0.003914    2.089863       0.386811
# 12213  0.004834    2.046862       0.383561
# 11345  0.004417    1.956559       0.372554
# 11317  0.005038    1.935058       0.370768
# 13025  0.003840    1.880421       0.361838
# 15424  0.003540    1.862494       0.358908
# 14551  0.003701    1.848550       0.357152

# %%
rules_df = rules_df.sort_values(by='lift', ascending=False)

print("Association rules with the highest lift:")
rules_df.head(10)
# Out:
# Association rules with the highest lift:
#                                    antecedents  \
# 15398  (whole milk, sausage, other vegetables)
# 15411                     (rolls/buns, yogurt)
# 15403   (rolls/buns, yogurt, other vegetables)
# 15406                    (whole milk, sausage)
# 13013                    (whole milk, sausage)
# 13016                           (curd, yogurt)
# 15399        (whole milk, sausage, rolls/buns)
# 15410               (yogurt, other vegetables)
# 15396   (whole milk, yogurt, other vegetables)
# 15413                    (sausage, rolls/buns)
#
#                                    consequents  antecedent support  \
# 15398                     (rolls/buns, yogurt)            0.050282
# 15411  (whole milk, sausage, other vegetables)            0.111339
# 15403                    (whole milk, sausage)            0.052335
# 15406   (rolls/buns, yogurt, other vegetables)            0.106978
# 13013                           (curd, yogurt)            0.106978
# 13016                    (whole milk, sausage)            0.040277
# 15399               (yogurt, other vegetables)            0.048743
# 15410        (whole milk, sausage, rolls/buns)            0.120318
# 15396                    (sausage, rolls/buns)            0.071832
# 15413   (whole milk, yogurt, other vegetables)            0.082350
#
#        consequent support   support  confidence      lift  leverage  \
# 15398            0.111339  0.013597    0.270408  2.428689  0.007998
# 15411            0.050282  0.013597    0.122120  2.428689  0.007998
# 15403            0.106978  0.013597    0.259804  2.428575  0.007998
# 15406            0.052335  0.013597    0.127098  2.428575  0.007998
# 13013            0.040277  0.010005    0.093525  2.322046  0.005696
# 13016            0.106978  0.010005    0.248408  2.322046  0.005696
# 15399            0.120318  0.013597    0.278947  2.318415  0.007732
# 15410            0.048743  0.013597    0.113006  2.318415  0.007732
# 15396            0.082350  0.013597    0.189286  2.298554  0.007681
# 15413            0.071832  0.013597    0.165109  2.298554  0.007681
#
#        conviction  zhangs_metric
# 15398    1.218025       0.619400
# 15411    1.081831       0.661957
# 15403    1.206467       0.620721
# 15406    1.085650       0.658702
# 13013    1.058742       0.637549
# 13016    1.188173       0.593239
# 15399    1.219997       0.597810
# 15410    1.072451       0.646451
# 15396    1.131903       0.608665
# 15413    1.111724       0.615642

# %%
# Filter the itemsets to find those that include "whole milk"
other_vegetables_rules = rules[rules['antecedents'].apply(lambda x: 'whole milk' in x) | 
                               rules['consequents'].apply(lambda x: 'whole milk' in x)]
top_other_vegetables_rules = other_vegetables_rules.sort_values(by='support', ascending=False).head(10)

print("Top 10 most frequent items purchased together with 'other vegetables':")
top_other_vegetables_rules
# Out:
# Top 10 most frequent items purchased together with 'other vegetables':
#              antecedents         consequents  antecedent support  \
# 1868        (whole milk)  (other vegetables)            0.458184
# 1869  (other vegetables)        (whole milk)            0.376603
# 2049        (rolls/buns)        (whole milk)            0.349666
# 2048        (whole milk)        (rolls/buns)            0.458184
# 2187              (soda)        (whole milk)            0.313494
# 2186        (whole milk)              (soda)            0.458184
# 2251            (yogurt)        (whole milk)            0.282966
# 2250        (whole milk)            (yogurt)            0.458184
# 2226        (whole milk)    (tropical fruit)            0.458184
# 2227    (tropical fruit)        (whole milk)            0.233710
#
#       consequent support   support  confidence      lift  leverage  \
# 1868            0.376603  0.191380    0.417693  1.109106  0.018827
# 1869            0.458184  0.191380    0.508174  1.109106  0.018827
# 2049            0.458184  0.178553    0.510638  1.114484  0.018342
# 2048            0.349666  0.178553    0.389698  1.114484  0.018342
# 2187            0.458184  0.151103    0.481997  1.051973  0.007465
# 2186            0.313494  0.151103    0.329787  1.051973  0.007465
# 2251            0.458184  0.150590    0.532185  1.161510  0.020940
# 2250            0.282966  0.150590    0.328667  1.161510  0.020940
# 2226            0.233710  0.116470    0.254199  1.087672  0.009388
# 2227            0.458184  0.116470    0.498353  1.087672  0.009388
#
#       conviction  zhangs_metric
# 1868    1.070564       0.181562
# 1869    1.101643       0.157802
# 2049    1.107190       0.157955
# 2048    1.065592       0.189591
# 2187    1.045971       0.071966
# 2186    1.024310       0.091184
# 2251    1.158185       0.193926
# 2250    1.068076       0.256640
# 2226    1.027473       0.148768
# 2227    1.080076       0.105189
